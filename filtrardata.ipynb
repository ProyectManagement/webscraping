# %%
import pandas as pd

# Cargar los archivos CSV
alumnos_df = pd.read_csv('csv/alumnos.csv')
carreras_df = pd.read_csv('csv/carreras.csv')
encuestas_df = pd.read_csv('csv/encuestas.csv')
grupos_df = pd.read_csv('csv/grupos.csv')
predicciones_df = pd.read_csv('csv/predicciones.csv')

# Función para mostrar información básica de los DataFrames
def mostrar_info(df, nombre):
    print(f"\nInformación de {nombre}:")
    print(f"Total de registros: {len(df)}")
    print("\nPrimeras filas:")
    print(df.head())
    print("\nColumnas disponibles:")
    print(df.columns.tolist())

# Mostrar información de cada DataFrame
mostrar_info(alumnos_df, "alumnos")
mostrar_info(carreras_df, "carreras")
mostrar_info(encuestas_df, "encuestas")
mostrar_info(grupos_df, "grupos")
mostrar_info(predicciones_df, "predicciones")

# Función para unir datos de alumnos con sus carreras y grupos
def unir_datos_alumnos(alumnos, carreras, grupos):
    # Primero unir alumnos con carreras
    merged = pd.merge(alumnos, carreras, left_on='id_carrera', right_on='_id', how='left')
    merged = merged.rename(columns={'nombre_y': 'nombre_carrera'})
    
    # Luego unir con grupos
    merged = pd.merge(merged, grupos, left_on='id_grupo', right_on='_id', how='left')
    merged = merged.rename(columns={'nombre': 'nombre_grupo'})
    
    # Seleccionar columnas relevantes
    resultado = merged[['id_alumno', 'nombre_x', 'app', 'apm', 'nombre_carrera', 'nombre_grupo']]
    return resultado.rename(columns={'nombre_x': 'nombre'})

# Unir datos de alumnos
alumnos_completos = unir_datos_alumnos(alumnos_df, carreras_df, grupos_df)
print("\nDatos completos de alumnos:")
print(alumnos_completos.head())

# Función para analizar encuestas
def analizar_encuestas(encuestas):
    # Filtrar encuestas completas (con correo)
    encuestas_completas = encuestas[encuestas['correo'].notna()]
    
    # Estadísticas básicas
    print(f"\nTotal de encuestas: {len(encuestas)}")
    print(f"Encuestas completas: {len(encuestas_completas)}")
    
    # Análisis por género
    if 'genero' in encuestas.columns:
        print("\nDistribución por género:")
        print(encuestas['genero'].value_counts())
    
    # Análisis por programa educativo
    if 'programa_educativo' in encuestas.columns:
        print("\nDistribución por programa educativo:")
        print(encuestas['programa_educativo'].value_counts())
    
    return encuestas_completas

# Analizar encuestas
encuestas_completas = analizar_encuestas(encuestas_df)

# Función para unir predicciones con alumnos
def unir_predicciones(predicciones, alumnos):
    # Verificar si hay datos válidos en id_alumno
    if predicciones['id_alumno'].isna().all():
        print("\nAdvertencia: No hay datos válidos en 'id_alumno' en las predicciones.")
        return pd.DataFrame(columns=['id_alumno', 'nombre', 'app', 'apm', 'riesgo'])
    
    # Convertir a tipo string para evitar problemas de tipo
    alumnos['id_alumno'] = alumnos['id_alumno'].astype(str)
    predicciones['id_alumno'] = predicciones['id_alumno'].astype(str)
    
    # Filtrar predicciones con id_alumno válido
    predicciones_validas = predicciones[predicciones['id_alumno'].notna()]
    
    # Unir con datos de alumnos
    merged = pd.merge(predicciones_validas, alumnos, on='id_alumno', how='left')
    
    # Seleccionar columnas relevantes
    resultado = merged[['id_alumno', 'nombre', 'app', 'apm', 'riesgo']]
    return resultado

# Unir predicciones
predicciones_alumnos = unir_predicciones(predicciones_df, alumnos_df)
print("\nPredicciones de riesgo por alumno:")
print(predicciones_alumnos.head())

# Guardar datos procesados
alumnos_completos.to_csv('alumnos_procesados.csv', index=False)
encuestas_completas.to_csv('encuestas_procesadas.csv', index=False)
predicciones_alumnos.to_csv('predicciones_procesadas.csv', index=False)
# Out:
# Información de alumnos:
# Total de registros: 14
#
# Primeras filas:
#                         _id    nombre      app        apm  \
# 0  65e9f1c8a1b2c3d4e5f67932    Daniel  Mendoza      López
# 1  65e9f1c8a1b2c3d4e5f67930      Luis    Gómez  Fernández
# 2  65e9f1c8a1b2c3d4e5f67931   Hamblet    Ariel    Aguilar
# 3  65e9f1c8a1b2c3d4e5f67933  Berenice  Anzaldo    Aguilar
# 4  67e0fc8eff0a98cbb20b8de3      Juan      NaN        NaN
#
#                  id_carrera                  id_grupo  id_alumno  \
# 0  65e9f1c8a1b2c3d4e5f67910  65e9f1c8a1b2c3d4e5f67921  222210708
# 1  65e9f1c8a1b2c3d4e5f67910  65e9f1c8a1b2c3d4e5f67920  222210709
# 2  65e9f1c8a1b2c3d4e5f67910  65e9f1c8a1b2c3d4e5f67920  222210613
# 3  65e9f1c8a1b2c3d4e5f67910  65e9f1c8a1b2c3d4e5f67921  222210689
# 4  67d7a402693e07166103f482  67d7a45f693e07166103f485  222210636
#
#   apellido_paterno apellido_materno programa_educativo                curp  \
# 0              NaN              NaN                NaN                 NaN
# 1              NaN              NaN                NaN                 NaN
# 2              NaN              NaN                NaN                 NaN
# 3              NaN              NaN                NaN                 NaN
# 4          Ramirez          Morelos               TICS  RAMJ040131HMCMRNA4
#
#           rfc       sexo  genero estado_civil               updated_at  \
# 0         NaN        NaN     NaN          NaN                      NaN
# 1         NaN        NaN     NaN          NaN                      NaN
# 2         NaN        NaN     NaN          NaN                      NaN
# 3         NaN        NaN     NaN          NaN                      NaN
# 4  RAMJ040131  Masculino  Hombre      Soltero  2025-03-24 06:32:46.521
#
#                 created_at
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4  2025-03-24 06:32:46.521
#
# Columnas disponibles:
# ['_id', 'nombre', 'app', 'apm', 'id_carrera', 'id_grupo', 'id_alumno', 'apellido_paterno', 'apellido_materno', 'programa_educativo', 'curp', 'rfc', 'sexo', 'genero', 'estado_civil', 'updated_at', 'created_at']
#
# Información de carreras:
# Total de registros: 2
#
# Primeras filas:
#                         _id  \
# 0  67d7a402693e07166103f482
# 1  67d7a402693e07166103f483
#
#                                               nombre               updated_at  \
# 0     Ingeniería en Desarrollo y gestion de Software  2025-03-17 04:24:32.743
# 1  Ingeniería en redes inteligentes y ciberseguridad  2025-03-17 04:24:34.672
#
#                 created_at
# 0  2025-03-17 04:24:32.743
# 1  2025-03-17 04:24:34.672
#
# Columnas disponibles:
# ['_id', 'nombre', 'updated_at', 'created_at']
#
# Información de encuestas:
# Total de registros: 15
#
# Primeras filas:
#                         _id                 correo                  id_grupo  \
# 0  67de1a0aa71f355cd80b8a02       example@mail.com  67d7a45f693e07166103f485
# 1  67de351ca71f355cd80b8a03                    NaN                       NaN
# 2  67de6a504499e9ed780ee1d2       example@mail.com  67d7a45f693e07166103f485
# 3  67deeae211bbf6cc9000eb42       example@mail.com  67d7a45f693e07166103f485
# 4  67deee29c0040917a6047522  al222210636@gmail.com  67d7a460693e07166103f486
#
#                  id_carrera        programa_educativo   nombre  \
# 0  67d7a402693e07166103f482  Licenciatura en Software     Juan
# 1                       NaN                       NaN      NaN
# 2  67d7a402693e07166103f482  Licenciatura en Software   Daniel
# 3  67d7a402693e07166103f482  Licenciatura en Software     EMMA
# 4  67d7a402693e07166103f482                      TICS  Ricardo
#
#   apellido_paterno apellido_materno                 curp            rfc  ...  \
# 0            Perez            Lopez   JUAN780101HNPLRP09  JUAP780101HPL  ...
# 1              NaN              NaN                  NaN            NaN  ...
# 2            Perez            Lopez   JUAN780101HNPLRP09  JUAP780101HPL  ...
# 3          Lzacano          Ramirez   JUAN780101HNPLRP09  JUAP780101HPL  ...
# 4           romero            Silva  RRSA040607HDISKDFKJ     RRSA040607  ...
#
#                                contacto_emergencia_2  \
# 0  {'nombre': 'Carlos Perez', 'telefono': '333654...
# 1                                                NaN
# 2  {'nombre': 'Carlos Perez', 'telefono': '333654...
# 3  {'nombre': 'Carlos Perez', 'telefono': '333654...
# 4  {'nombre': 'Fanny Camacho', 'telefono': '72245...
#
#                             aspectos_socioeconomicos  \
# 0  {'trabaja': 'Sí', 'horas_trabajo': '40', 'nomb...
# 1                                                NaN
# 2  {'trabaja': 'Sí', 'horas_trabajo': '40', 'nomb...
# 3  {'trabaja': 'Sí', 'horas_trabajo': '40', 'nomb...
# 4  {'trabaja': 'Sí', 'horas_trabajo': '0', 'nombr...
#
#                            aportantes_gasto_familiar  \
# 0  {'padre': True, 'madre': True, 'hermanos': Fal...
# 1                                                NaN
# 2  {'padre': True, 'madre': True, 'hermanos': Fal...
# 3  {'padre': True, 'madre': True, 'hermanos': Fal...
# 4  {'padre': '1', 'madre': '1', 'hermanos': '1', ...
#
#    edad_integrantes_familia  \
# 0              [55, 52, 30]
# 1                       NaN
# 2              [55, 52, 30]
# 3              [55, 52, 30]
# 4        ['40', '20', '34']
#
#                                    condiciones_salud  \
# 0  {'condiciones': ['Hipertensión'], 'otro': 'Nin...
# 1                                                NaN
# 2  {'condiciones': ['Hipertensión'], 'otro': 'Nin...
# 3  {'condiciones': ['Hipertensión'], 'otro': 'Nin...
# 4  {'condiciones': 'Ninguno', 'otro': 'Ninguno', ...
#
#                                   analisis_academico  \
# 0  {'tipo_escuela_previa': 'Pública', 'modalidad_...
# 1                                                NaN
# 2  {'tipo_escuela_previa': 'Pública', 'modalidad_...
# 3  {'tipo_escuela_previa': 'Pública', 'modalidad_...
# 4  {'tipo_escuela_previa': 'Pública', 'modalidad_...
#
#                expectativas_educativas_ocupacionales               updated_at  \
# 0  {'espacio_laboral_preferido': 'Empresa Tecnoló...  2025-03-22 02:01:44.563
# 1                                                NaN  2025-03-22 03:57:16.555
# 2  {'espacio_laboral_preferido': 'Empresa Tecnoló...  2025-03-22 07:44:16.514
# 3  {'espacio_laboral_preferido': 'Empresa Tecnoló...  2025-03-22 16:52:50.119
# 4  {'espacio_laboral_preferido': 'Empresa Tecnolo...  2025-03-22 17:06:49.209
#
#                 created_at id_alumno
# 0  2025-03-22 02:01:44.563       NaN
# 1  2025-03-22 03:57:16.555       NaN
# 2  2025-03-22 07:44:16.514       NaN
# 3  2025-03-22 16:52:50.119       NaN
# 4  2025-03-22 17:06:49.209       NaN
#
# [5 rows x 39 columns]
#
# Columnas disponibles:
# ['_id', 'correo', 'id_grupo', 'id_carrera', 'programa_educativo', 'nombre', 'apellido_paterno', 'apellido_materno', 'curp', 'rfc', 'sexo', 'genero', 'estado_civil', 'numero_hijos', 'depende_economicamente', 'religion', 'grupo_sanguineo', 'fecha_nacimiento', 'edad', 'pais_nacimiento', 'estado_nacimiento', 'municipio_nacimiento', 'telefono_celular', 'telefono_casa', 'correo_personal', 'redes_sociales', 'direccion', 'referencias_domicilio', 'contacto_emergencia_1', 'contacto_emergencia_2', 'aspectos_socioeconomicos', 'aportantes_gasto_familiar', 'edad_integrantes_familia', 'condiciones_salud', 'analisis_academico', 'expectativas_educativas_ocupacionales', 'updated_at', 'created_at', 'id_alumno']
#
# Información de grupos:
# Total de registros: 6
#
# Primeras filas:
#                         _id   nombre                id_carrera  \
# 0  67d7a45f693e07166103f485  IDGS-81  65e9f1c8a1b2c3d4e5f67910
# 1  67d7a460693e07166103f486  IDGS-82  65e9f1c8a1b2c3d4e5f67911
# 2  67d7a461693e07166103f487  IDGS-83  65e9f1c8a1b2c3d4e5f67912
# 3  67e1f17496c6160377f484b9  IRIC-81  65e9f1c8a1b2c3d4e5f67910
# 4  67e1f1ac96c6160377f484bb  IRIC-82  65e9f1c8a1b2c3d4e5f67910
#
#                 updated_at               created_at
# 0  2025-03-17 04:26:07.791  2025-03-17 04:26:07.791
# 1  2025-03-17 04:26:08.449  2025-03-17 04:26:08.449
# 2  2025-03-17 04:26:09.090  2025-03-17 04:26:09.090
# 3  2025-03-17 04:26:07.791  2025-03-17 04:26:07.791
# 4  2025-03-17 04:26:07.791  2025-03-17 04:26:07.791
#
# Columnas disponibles:
# ['_id', 'nombre', 'id_carrera', 'updated_at', 'created_at']
#
# Información de predicciones:
# Total de registros: 43
#
# Primeras filas:
#                         _id riesgo               id_encuesta id_alumno
# 0  65e9f1c8a1b2c3d4e5f67952   Bajo                       NaN       NaN
# 1  65e9f1c8a1b2c3d4e5f67951  Medio                       NaN       NaN
# 2  65e9f1c8a1b2c3d4e5f67950   Alto                       NaN       NaN
# 3  67e11594dfbff8739cc78797   Bajo  67de1a0aa71f355cd80b8a02       NaN
# 4  67e11595dfbff8739cc78798   Bajo  67de351ca71f355cd80b8a03       NaN
#
# Columnas disponibles:
# ['_id', 'riesgo', 'id_encuesta', 'id_alumno']
#
# Datos completos de alumnos:
#    id_alumno    nombre      app        apm  \
# 0  222210708    Daniel  Mendoza      López
# 1  222210709      Luis    Gómez  Fernández
# 2  222210613   Hamblet    Ariel    Aguilar
# 3  222210689  Berenice  Anzaldo    Aguilar
# 4  222210636      Juan      NaN        NaN
#
#                                    nombre_carrera nombre_grupo
# 0                                             NaN          NaN
# 1                                             NaN          NaN
# 2                                             NaN          NaN
# 3                                             NaN          NaN
# 4  Ingeniería en Desarrollo y gestion de Software      IDGS-81
#
# Total de encuestas: 15
# Encuestas completas: 9
#
# Distribución por género:
# genero
# Hombre    7
# Mujer     2
# Name: count, dtype: int64
#
# Distribución por programa educativo:
# programa_educativo
# TICS                        4
# Licenciatura en Software    3
# Ing Software                2
# Name: count, dtype: int64
#
# Predicciones de riesgo por alumno:
#   id_alumno nombre  app  apm riesgo
# 0       nan    NaN  NaN  NaN   Bajo
# 1       nan    NaN  NaN  NaN  Medio
# 2       nan    NaN  NaN  NaN   Alto
# 3       nan    NaN  NaN  NaN   Bajo
# 4       nan    NaN  NaN  NaN   Bajo
